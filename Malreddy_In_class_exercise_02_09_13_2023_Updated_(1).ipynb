# %% [markdown]
# <a href="https://colab.research.google.com/github/MPrasanna14/prasanna_INFO5731_Fall2023/blob/main/Malreddy_In_class_exercise_02_09_13_2023_Updated_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The second In-class-exercise (09/13/2023, 40 points in total)

# %% [markdown]
# Kindly use the provided .ipynb document to write your code or respond to the questions. Avoid generating a new file.
# Execute all the cells before your final submission.

# %% [markdown]
# This in-class exercise is due tomorrow September 14, 2023 at 11:59 PM. No late submissions will be considered.

# %% [markdown]
# The purpose of this exercise is to understand users' information needs, then collect data from different sources for analysis.

# %% [markdown]
# Question 1 (10 points): Describe an interesting research question (or practical question or something innovative) you have in mind, what kind of data should be collected to answer the question(s)? How many data needed for the analysis? The detail steps for collecting and save the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''
One research topic that I'm interested in is......
How does amazon customer reviews and ratings affect online buyers' purchase decisions?
Does the tone of reviews have an impact on sales for particular product categories?

Kind of data needed for analysis are Customer reviews and ratings, product sales data i.e., number of units sold,
revenue and price, product category etc.

Gather an ample number of reviews from a range of product categories for data analysis.
Obtain sales information for similar products and time periods as reviews and ensure precise categorization of products. Also analyze the sentiment of reviews. And
finally clean up and merge data before analysis.

Data Collection Steps:
Obtain API access or use web scraping for review data.
Clean collected data.
Conduct sentiment analysis.
Merge data sources based on product identifiers.
Analyze the relationship between review sentiment and product sales.
Store integrated data securely for future reference.

'''

# %% [markdown]
# Question 2 (10 points): Write python code to collect 1000 data samples you discussed above.

# %%
# You code here (Please add comments in the code):

import pandas as pd
import random
import string
from datetime import datetime, timedelta

# Generate random product categories
categories = ["Electronics", "Books", "Clothing", "Home and Kitchen", "Toys"]

# Generate random customer reviews and ratings
def generate_random_review():
    rating = random.randint(1, 5)
    review_text = ''.join(random.choices(string.ascii_letters + string.digits, k=random.randint(20, 200)))
    return rating, review_text

# Generate random product sales data
def generate_random_sales():
    units_sold = random.randint(1, 100)
    revenue = random.uniform(10, 1000)
    price = revenue / units_sold
    return units_sold, revenue, price

# Generate sample data
data = []
for _ in range(1000):
    category = random.choice(categories)
    rating, review_text = generate_random_review()
    units_sold, revenue, price = generate_random_sales()
    date = (datetime.now() - timedelta(days=random.randint(1, 365))).strftime("%Y-%m-%d")

    data.append([category, rating, review_text, units_sold, revenue, price, date])

# Create a DataFrame
df = pd.DataFrame(data, columns=["Category", "Rating", "Review", "Units Sold", "Revenue", "Price", "Date"])
df
# Out:
#              Category  Rating  \
# 0            Clothing       2
# 1               Books       2
# 2            Clothing       5
# 3    Home and Kitchen       2
# 4                Toys       4
# ..                ...     ...
# 995  Home and Kitchen       5
# 996          Clothing       1
# 997             Books       4
# 998          Clothing       2
# 999             Books       4
#
#                                                 Review  Units Sold  \
# 0    g466Nk1apFcjBMnW4AS6ng0hu5gmVWLX7vRcxaJQxRBAxy...          27
# 1    1wSyPrLamH0GGHtRjIuaMsauusY3DSqxtNfLfcBfqPTvRG...          41
# 2    GHSbSifnO5p1hd0xdCXxWiUPHclsqwHtErGFVzykTrP6sq...          79
# 3    BSkNhm0rGJpKwWA7revBAJ8JMR56WmreRpaSu4MNbRLV82...          98
# 4    gAu2TUZPW1tDj0fF7ytQlLNZoEtUMPxhHVq3MOz25JaQTt...          95
# ..                                                 ...         ...
# 995  QlWW2Fuwp7142fmn3gqWi1uxvCTYf94tdOo9j312tizcwk...          24
# ...

# %% [markdown]
# Question 3 (10 points): Write python code to collect 1000 articles from Google Scholar (https://scholar.google.com/), Microsoft Academic (https://academic.microsoft.com/home), or CiteSeerX (https://citeseerx.ist.psu.edu/index), or Semantic Scholar (https://www.semanticscholar.org/), or ACM Digital Libraries (https://dl.acm.org/) with the keyword "information retrieval". The articles should be published in the last 10 years (2013-2023).
#
# The following information of the article needs to be collected:
#
# (1) Title
#
# (2) Venue/journal/conference being published
#
# (3) Year
#
# (4) Authors
#
# (5) Abstract

# %%
# You code here (Please add comments in the code):
import requests
import pandas as pd

def collect_articles(query, num_articles, start_year, end_year):
    articles = []
    for i in range(0, num_articles, 100):
        url = "https://api.semanticscholar.org/graph/v1/paper/search?query={}&offset={}&limit=100&year={}-{}&fields=title,year,venue,journal,publicationTypes,authors,abstract".format(query, i, start_year, end_year)
        response = requests.get(url)
        results = response.json()
        if 'error' in results:
            print("Results: ", results)
            break
        for result in results['data']:
            article = {}
            article['title'] = result.get('title', '')
            article['year'] = result.get('year', '')
            article['venue'] = result.get('venue', '')
            article['journal'] = result.get('journal', '')
            article['publicationTypes'] = result.get('publicationTypes', [])
            article['authors'] = result.get('authors', [])
            article['abstract'] = result.get('abstract', '')
            articles.append(article)
    return articles

query = "information retrieval"
num_articles = 1000
start_year = 2012
end_year = 2022
articles = collect_articles(query, num_articles, start_year, end_year)

df = pd.DataFrame(articles)
print(df.head())
print(df.tail())
# Out:
#                                                title  year  \
# 0  BEIR: A Heterogenous Benchmark for Zero-shot E...  2021
# 1  Pyserini: A Python Toolkit for Reproducible In...  2021
# 2  InPars: Unsupervised Dataset Generation for In...  2022
# 3  Neural Approaches to Conversational Informatio...  2022
# 4  Reduce, Reuse, Recycle: Green Information Retr...  2022
#
#                                                venue  \
# 0                    NeurIPS Datasets and Benchmarks
# 1  Annual International ACM SIGIR Conference on R...
# 2  Annual International ACM SIGIR Conference on R...
# 3                   The Information Retrieval Series
# 4  Annual International ACM SIGIR Conference on R...
#
#                                              journal  \
# 0      {'name': 'ArXiv', 'volume': 'abs/2104.08663'}
# 1  {'name': 'Proceedings of the 44th Internationa...
# 2  {'name': 'Proceedings of the 45th Internationa...
# 3  {'name': 'Neural Approaches to Conversational ...
# ...

# %% [markdown]
# Do either of the question-4 tasks given below.

# %% [markdown]
# Question 4 (10 points): Write python code to collect 1000 posts from Twitter, or Facebook, or Instagram. You can either use hashtags, keywords, user_name, user_id, or other information to collect the data.
#
# The following information needs to be collected:
#
# (1) User_name
#
# (2) Posted time
#
# (3) Text

# %%
# You code here (Please add comments in the code):

import instaloader
import pandas as pd
# Initialize an Instaloader instance
L = instaloader.Instaloader()

 #Login to your Instagram account (if needed)
 #L.login('your_username', 'your_password')

# Replace 'instagram_user' with the username you want to collect posts from
profile = instaloader.Profile.from_username(L.context, 'anushkasharma')

# Create a list to store the collected data
collected_data = []

# Specify the number of posts you want to collect (e.g., 1000)
num_posts_to_collect = 1100

# Iterate through the user's posts and collect data
for post in profile.get_posts():
    if len(collected_data) >= num_posts_to_collect:
        break  # Stop collecting after reaching the desired number of posts

    user_name = post.owner_username
    posted_time = post.date_utc
    text = post.caption

    # Append the data to the list
    collected_data.append({
        'User_name': user_name,
        'Posted_time': posted_time,
        'Text': text,
    })

# Create a DataFrame from the collected data
df = pd.DataFrame(collected_data)

# Print the DataFrame
df
# Out:
# C:\Users\gonug\Anaconda3\lib\site-packages\win_unicode_console\__init__.py:31: RuntimeWarning: sys.stdin.encoding == 'cp1252', whereas sys.stdout.encoding == 'UTF-8', readline hook consumer may assume they are the same
#   readline_hook.enable(use_pyreadline=use_pyreadline)
# C:\Users\gonug\Anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\gonug\Anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
# C:\Users\gonug\Anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.23-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
#           User_name         Posted_time  \
# 0     anushkasharma 2023-09-04 06:39:33
# 1     anushkasharma 2023-08-22 06:46:57
# 2     anushkasharma 2023-08-21 06:50:37
# 3     anushkasharma 2023-08-20 06:30:30
# 4     anushkasharma 2023-07-09 16:11:49
# ...             ...                 ...
# 1095  anushkasharma 2016-03-07 17:00:25
# ...

# %% [markdown]
# Question 4 (10 points):
#
# In this task, you are required to identify and utilize online tools for web scraping data from websites without the need for coding, with a specific focus on Parsehub. The objective is to gather data and save it in formats like CSV, Excel, or any other suitable file format.
#
# You have to mention an introduction to the tool which ever you prefer to use, steps to follow for web scrapping and the final output of the data collected.
#
# Upload a document (Word or PDF File) in the same repository and you can add the link in the ipynb file.

# %%
https://github.com/MPrasanna14/prasanna_INFO5731_Fall2023/blob/main/Prasanna%20Malreddy_INClass_Eercise_02_Question%204.pdf
